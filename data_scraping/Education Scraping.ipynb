# %%
# importing libraries and packages
import urllib.request
from bs4 import BeautifulSoup
from langdetect import detect
import GetOldTweets3 as got
import pandas as pd
import ssl
import requests
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # 1) Scraping Twitter

# %% [markdown]
# ### @Rwanda_Edu (Ministry of Education) & @REBRwanda (Rwanda Education Board)

# %%
"""
Function to get Tweets data from Twitter
"""
def get_twitter_data(handle, start_date, end_date):
    # filters
    filters = got.manager.TweetCriteria().setUsername(handle)\
                          .setSince(start_date)\
                          .setUntil(end_date)\
    
    # scraping
    tweet = got.manager.TweetManager.getTweets(filters)
    
    # creating list
    data = [[tw.username,
                tw.text,
                tw.date,
                tw.retweets,
                tw.favorites,
                tw.mentions,
                tw.hashtags] for tw in tweet]
    
    # transforming list into dataframe
    tweets_df = pd.DataFrame(data, columns = ['username', 
                                              'tweet', 
                                              'date', 
                                              'favorites', 
                                              'retweets', 
                                              'mentions', 
                                              'hashTags'])
    
    return tweets_df

# %%
# Twitter accounts to scrape
twitter_sources = ['rwanda_edu', 'REBRwanda']
# getting tweets from the sources from April 1st 2020 until August 13th 2020
tweets_df = get_twitter_data(twitter_sources, 
                     start_date = "2020-04-01", 
                     end_date = "2020-08-13").sort_values('date', ascending=False)

# %%
tweets_df
# Out:
#        username                                              tweet  \
# 0    Rwanda_Edu  The Minister of Education .@Dr_Uwamariya appre...
# 1    Rwanda_Edu  Discussions centered on enhancement of impacti...
# 2    Rwanda_Edu  The Minister of Education @Dr_Uwamariya held a...
# 3     REBRwanda  La formation des professeurs de français dans ...
# 4     REBRwanda  En discussion avec les professeurs de français...
# 5     REBRwanda  Lors du lancement de la formation, le directeu...
# 6     REBRwanda  Aujourd'hui, le directeur général du Rwanda Ed...
# 7    Rwanda_Edu  Munyarwanda, umurimo wose waba ukora, umuganda...
# 8    Rwanda_Edu  The ongoing countrywide school construction st...
# 9     REBRwanda  Mwiriwe neza Bwana Tom Ndahiro, iki gitabo uvu...
# 10    REBRwanda  REB yishimiye kubagezaho ingengabihe y'amasomo...
# 11    REBRwanda  Mwaramutse neza Anne Marie, ni byo koko ikosa ...
# 12   Rwanda_Edu  Minisiteri y'Uburezi yifurije Abafatanyabikorw...
# 13    REBRwanda  So far Rwanda Education Board through CADIE Pr...
# 14    REBRwanda  In discussion with Deputy Counsellor at the Em...
# 15    REBRwanda  Today,DG REB, Dr.Ndayambaje Irenee received th...
# 16    REBRwanda  Mwiriwe neza Bwana Mukunzi; Oya, results slip ...
# 17    REBRwanda  REB yishimiye kubagezaho ingengabihe y'amasomo...
# 18   Rwanda_Edu  Minisiteri y’Uburezi iramenyesha ababyeyi ko g...
# 19    REBRwanda  Aganira na @rbarwanda,Umuyobozi Mukuru wa REB,...
# 20    REBRwanda  Aganira na @rbarwanda, Umuyobozi Mukuru wa REB...
# 21    REBRwanda  Mukiganiro na @rbarwanda , Umugenzuzi Mukuru m...
# 22    REBRwanda  Aganira na @rbarwanda Umugenzuzi Mukuru w'Irem...
# 23    REBRwanda  Mukiganiro na @rbarwanda , Umuyobozi Mukuru wa...
# 24    REBRwanda  Aganira na @rbarwanda ,Umuyobozi Mukuru wa REB...
# 21               @rbarwanda @Rwanda_Edu @RwandaPolytec
# 22                           @rbarwanda @RwandaPolytec
# 23                           @rbarwanda @RwandaPolytec
# 24         @rbarwanda @MTNRwanda @airtelrw @Rwanda_Edu
# 25                                      @RwandaPolytec
# 26                          @RwandaPolytec @Rwanda_Edu
# 27                          @Rwanda_Edu @RwandaPolytec
# 28                                    @Gasabo_District
# 29         @Rwanda_Edu @RwandaPolytec @Gasabo_District
# ..                                                 ...                   ...
# 384                                    @ClaudetteIrere              #COVID19
# 385                                    @ClaudetteIrere
# 386  @ClaudetteIrere @REBRwanda @Uni_Rwanda @Rwanda...
# 387                         @ClaudetteIrere @rbarwanda      #Rwanda #COVID19
# 388
# 389                                     @RwandaPolytec
# 390
# 391
# 392                      @rbarwanda @Rwanda_Edu @ndbje              #COVID19
# 393             @rbarwanda @Rwanda_Edu @ClaudetteIrere
# 394                      @rbarwanda @Rwanda_Edu @ndbje              #COVID19
# 395             @rbarwanda @Rwanda_Edu @ClaudetteIrere
# 396                      @rbarwanda @Rwanda_Edu @ndbje
# 397             @rbarwanda @Rwanda_Edu @ClaudetteIrere              #COVID19
# 398
# 399
# 400                                   @Radiorwanda_RBA
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410                                   @Radiorwanda_RBA
# 411
# 412
# 413
#
# [414 rows x 7 columns]

# %%
# verifying that every tweet has text value
print((tweets_df['tweet']=="").value_counts())
# removing tweet without text as we cannot determine language
tweets_df = tweets_df[tweets_df['tweet']!=""]
# Out:
# False    413
# True       1
# Name: tweet, dtype: int64

# %%
"""
Function to detect the language of each Tweet and to return list of languages
""" 
def get_tweet_language(df, col):
    return df.apply(
        lambda x: detect(x[col]),
        axis=1
    )

# %%
# getting the list of detected languages for the dataframe
language_list = get_tweet_language(tweets_df, 'tweet')

# %%
# checking the distribution of languages detected
print(language_list.value_counts())
# Out:
# en    200
# sw    199
# id      4
# fr      4
# tl      3
# hr      1
# tr      1
# sl      1
# dtype: int64

# %%
# as Kinyarwanda is not in the list of languages to be detected by the langdetect package, 
# we consider other languages than English and French to be Kinyarwanda
kinyarwanda = ["sw", "id", "so", "tl", "sl", "tr"]
new_language_list = ['kr' if n in kinyarwanda else n for n in language_list]

# %%
# adding the list of languages detected to the dataframe
tweets_df['language'] = new_language_list
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# finding which tweets have relevant labels
covid_related = ['covid']
tweets_df['tweet_search'] = tweets_df['tweet'].str.lower()
tweets_df['tweet_type'] = tweets_df.tweet_search.apply(lambda sentence: all(word in sentence for word in covid_related))
print(tweets_df['tweet_type'].value_counts())
# Out:
# False    380
# True      33
# Name: tweet_type, dtype: int64
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
tweets_df[tweets_df['tweet_type']]['tweet']
# Out:
# 21     Mukiganiro na @rbarwanda , Umugenzuzi Mukuru m...
# 23     Mukiganiro na @rbarwanda , Umuyobozi Mukuru wa...
# 24     Aganira na @rbarwanda ,Umuyobozi Mukuru wa REB...
# 44     .@Dr_Uwamariya aganira n’abaturage bari mu mug...
# 53     The chairman of @PSF_Rwanda Mr Robert Bapfakur...
# 67     She also visited @IPRCMusanze and Muhabura Int...
# 75     .@Dr_Uwamariya, the Minister of Education repr...
# 76     Four major areas had been identified with spec...
# 77     The 1st EU-AU Research & Innovation Ministeria...
# 106    The inspection also aims to assess measures un...
# 113    Umunyamabanga wa Leta ushinzwe amashuri abanza...
# 154    .@Dr_Uwamariya :The Financial Year 2020/21 is ...
# 156    .@Dr_Uwamariya : Following the outbreak &amp; ...
# 161    Happening today 25 June 2020: There is a Forwa...
# 187    Simon, ntacyo bitwaye gusa musabwa kubahiriza ...
# 188    @Dr_Uwamariya : " Ntacyo byaba bimaze twubatse...
# 203    Dear students and parents, stay tuned to a liv...
# 204    Director General of Rwanda Education Board,Dr....
# 228    Dear students and parents, stay tuned to a liv...
# 251    As we are waiting for schools reopening in Sep...
# 260    As activities of classrooms and latrines const...
# 261    Mu gihe ibikorwa byo kubaka amashuri n'ubwiher...
# 265    (3)@gtwagirayezu: Covid19 has been an opportun...
# 267    (1)During @RwandaSquare Tv show on @RwandaTv, ...
# 270    In discussion with @RwandaTV,Minister of State...
# 286    Schools will remain closed until September 202...
# 292    Nyuma yuko @RwandaInfra yemereye imwe mu mishi...
# 294    Following @RwandaInfra clearance of some proje...
# 384    .@ClaudetteIrere : Turakangurira abanyeshuri g...
# 387    . @ClaudetteIrere, Umunyamabanga wa Leta muri ...
# 392    In discussion with @rbarwanda Director General...
# 394    Speaking to @rbarwanda , Director General of R...
# 397    Speaking to @rbarwanda ,Hon. Minister of State...
# Name: tweet, dtype: object

# %%
# exporting the tweets to a CSV file
tweets_df.to_csv('tweets_df.csv')

# %% [markdown]
# # 2) Scraping the Ministry Of Education website

# %%
# URL that contains the information to scrape
URL = "https://mineduc.gov.rw/index.php?id=166"

# %%
# getting the cookie access key
page = urllib.request.urlopen('https://mineduc.gov.rw/index.php?id=166')
page.read()
# Out:
# b"<html><script lang=javascript>\r\ndocument.cookie = '_accessKey2=Yp0iypgmHFIg2/Iwe6ydkYlrXqCnt0Z6'\r\nwindow.location.reload();\r\n</script></html>\r\n"

# %%
# scraping the page using the cookie access key from previous request
Cookies={'Cookie':r"_accessKey2=Yp0iypgmHFIg2/Iwe6ydkYlrXqCnt0Z6"}
Request=urllib.request.Request(url=URL,headers=Cookies)
cookieProcessor = urllib.request.HTTPCookieProcessor()
opener = urllib.request.build_opener(cookieProcessor)
response = opener.open(Request,timeout=100)
html_text = response.read()

# %%
# parsing the html content
soup = BeautifulSoup(html_text, 'html.parser')
headers = [p.get_text() for p in soup.find_all("b")]
text_page=soup.find('div').getText()
print(text_page)
# Out:
# info@mineduc.gov.rw
#
# Hotline 2028
#  Staff Mail
#
#
#  English  Kinyarwanda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     $(document).ready(function (){
#      var param1 = $(".previous-keyword").val();
#       $('.new-search-keyword').val(param1);
#     });
#
#
#
#
#
#
#
#
#
# MENU
#
#
#
#
#
#
# HOMEABOUT USMinistry OfficialsVisionMission of the MinistryDirectoratesDirector General of Education PlanningStaffStaff contactsMEDIANewsPress ReleaseSpeechesRESOURCELawsEducation LawsEducation OrdersMinisterial instructionsPoliciesStatisticsStatistical Year BooksData Collection ToolsReportsESSPESSP 2018-2024ESSP2013-2018ESSP2008-2012ESSP2004-2008SCHOOL CALENDARSMAP OF SCHOOLSPrimary SchoolsSecondary Ordinal LevelSecondary Advanced  LevelSecondary SchoolsBoarding Secondary SchoolsTeacher Training CollegesTechnical Secondary SchoolsVocational Training CentersPolytechnicsHigher EducationProcurement PlanSERVICESRequirements for Setting up a Private Higher Learning InstitutionLooking for Rwanda Student LoansIssuance of ‘Authentication of A’ Level CertificateIssuance of Academic TestimonialIssuance of ‘To Whom It May Concern’ (A qui de droit) for Secondary School lost certificatesIssuance of Secondary School lost transcripts (Bulletins)Service charterPROJECTSQuality Basic Education for Human Capital Development in RwandaQuality Basic Education for Human Capital Development in RwandaClimate ChangeClimate observatory in RwandaFAQsSUGGESTION BOX
#
#
#
#
#
#
#
#
#
# HOMEFAQs
#
# 				SCHOOL REOPENING: FREQUENTLY ASKED QUESTIONS
# 			School Reopening When will the schools reopen?As the Government continues to monitor the Covid-19 pandemic and the challenges it poses to different sectors, it has been decided that the earliest schools may reopen is September 2020. The detailed school calendar will be shared in due course. What happens when schools reopen?Primary and Secondary SchoolsThe school calendar year will start in September 2020 and end in May-June 2021. This accelerates the already planned adjustment to a September-June school year.When schools closed, Term 1 was almost ending, so it will be repeated to ensure all students are on the same page going forward.The exact dates for national exams will be communicated later.Higher Learning Institutions (HLIs)When HLIs closed, there were only two months remaining in the academic year. HLIs will resume the interrupted term in September 2020, and conclude the 2019-2020 academic in November 2020. They will reopen in December 2020 for the new intake and ensure they take necessary measures to follow the school calendar year that ends in May-June 2021.Disbursement of living allowances (bursary) for Government -sponsored students will resume when schools re-open in September.What about private schools that have continued teaching students online?All schools that follow the National Program will follow the school calendar year as determined by the Ministry of Education.  How does this decision affect international schools in Rwanda?  International schools will continue to follow international study programs without compromising existing health measures and guidelines.Should parents continue to pay school tuition fees?Schools that follow the national program are advised not to charge fees while they remain closed because of Covid-19 mitigation measures.Tuition fees that were paid for Term 1 were used in the January – March period and will not be refunded. Parents who had paid for a full school year will only be expected to pay for one term.What should schools do to get ready for reopening?Schools are advised to ensure they take necessary hygiene measures in preparation for reopening, including ensuring adequate washing facilities and making necessary renovations to enhance hygiene.TV, Radio and E-LearningWhat alternative ways has the Government put in place to facilitate students at home to continue learning?When schools closed in March 2020, the Ministry of Education in partnership with telecom companies immediately zero-rated e-learning platforms in a bid to facilitate students to access them at no cost. Additionally, radio and TV, with a much wider coverage, have been leveraged to air lessons. The schedule for these lessons is shared periodically on the Ministry’s online accounts and on radio.Students should continue to actively follow TV, radio, and e-learning activities until schools reopen.To complement the learning, a USSD-based quiz on different subjects is available at *134#. A few private universities have their e-learning platforms ready and zero-rated. Higher learning students are encouraged to reach out to their respective universities to enquire about e-learning facilities at their disposal.What about students who don’t have access to TV, radio, or internet?MINEDUC recognizes that the overall coverage of radio, TV, internet, and device ownership is limited and that a significant portion of the population does not have access to the above. Moreover, content for students with disabilities is not yet readily available. MINEDUC is working with partners to increase access to e-learning.When schools reopen, there will be special measures to ensure those who did not have proper access to e-learning facilities are not left behind.TeachersWhat facilities have been put in place for teachers during the lockdown?Just as e-learning platforms have been availed for students, teachers are encouraged to use them and to prepare lessons.  Additionally, there are various trainings and assessments that are being organiz ...
